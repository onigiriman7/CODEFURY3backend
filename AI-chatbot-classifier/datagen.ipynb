# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("names.csv")

# %%
df.head()
# Out:
#               name     village  experiece  skill1  skill2
# 0          barjraj  Aladakatti        NaN     NaN     NaN
# 1     ramdin verma   Bandakeri        NaN     NaN     NaN
# 2  sharat chandran    Budingod        NaN     NaN     NaN
# 3  birender mandal         NaN        NaN     NaN     NaN
# 4             amit         NaN        NaN     NaN     NaN

# %%
village = ['Aladakatti', 'Bandakeri', 'Budingod']
import random

village_gen = []
for i in range(int(1132/3)):
    village_gen.append(village[number])
print(village_gen)
# Out:
# ['Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Al
# ...

# %%
for i in range(int(1131/3)):
    village_gen.append('Bandakeri')
print(village_gen)
# Out:
# ['Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Al
# ...

# %%
for i in range(int(1131/3)):
    village_gen.append('Budingod')
print(village_gen)
# Out:
# ['Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Aladakatti', 'Al
# ...

# %%
v = np.asarray(village_gen)
df['village'] = v

# %%
df.head()
# Out:
#               name     village  experiece  skill1  skill2
# 0          barjraj  Aladakatti        NaN     NaN     NaN
# 1     ramdin verma  Aladakatti        NaN     NaN     NaN
# 2  sharat chandran  Aladakatti        NaN     NaN     NaN
# 3  birender mandal  Aladakatti        NaN     NaN     NaN
# 4             amit  Aladakatti        NaN     NaN     NaN

# %%
import sklearn
df = sklearn.utils.shuffle(df)

# %%
df.head()
# Out:
#                 name    village  experiece  skill1  skill2
# 591           vikash  Bandakeri        NaN     NaN     NaN
# 975   jitendra kumar   Budingod        NaN     NaN     NaN
# 794      anoop singh   Budingod        NaN     NaN     NaN
# 1048       durganand   Budingod        NaN     NaN     NaN
# 390            kiran  Bandakeri        NaN     NaN     NaN

# %%
field1 = 'construction'
field2 = 'factory worker'
field3 = 'security'
field4 = 'cleaner'

const = ['mason', 'construction worker', 'labourer', 'labor', 'labour']
fact = ['factory worker', 'machine operator', 'industry worker', 'machinery handler', 'production helper']
sec = ['security', 'watchman', 'guard', 'chaukidaar', 'warden']

skill1 = []
skill2 = []

for i in range(1131):
    arraynum1 = random.randint(0,2)
    if(arraynum1 == 0):
        indexnum = random.randint(0,4)
        skill1.append(const[indexnum])
    elif(arraynum1 == 1):
        indexnum = random.randint(0,4)
        skill1.append(fact[indexnum])
    elif(arraynum1 == 2):
        indexnum = random.randint(0,4)
        skill1.append(sec[indexnum])
    if arraynum1 == 0:
        arraynum2 = random.choice([1, 2])
    elif arraynum1 == 1:
        arraynum2 = random.choice([0,2])
    elif arraynum1 == 2:
        arraynum2 = random.choice([0,1])
        
    if(arraynum2 == 0):
        indexnum = random.randint(0,4)
        skill2.append(const[indexnum])
    elif(arraynum2 == 1):
        indexnum = random.randint(0,4)
        skill2.append(fact[indexnum])
    elif(arraynum2 == 2):
        indexnum = random.randint(0,4)
        skill2.append(sec[indexnum])

# %%
print(skill1)
# Out:
# ['production helper', 'factory worker', 'industry worker', 'labor', 'machinery handler', 'chaukidaar', 'labor', 'guard', 'construction worker', 'machine operator', 'labour', 'security', 'warden', 'production helper', 'security', 'security', 'labor', 'chaukidaar', 'guard', 'construction worker', 'warden', 'mason', 'labour', 'labour', 'guard', 'watchman', 'machine operator', 'mason', 'chaukidaar', 'factory worker', 'factory worker', 'chaukidaar', 'machinery handler', 'labor', 'watchman', 'labourer', 'labour', 'machinery handler', 'warden', 'watchman', 'factory worker', 'production helper', 'labourer', 'labor', 'warden', 'guard', 'watchman', 'factory worker', 'labor', 'labor', 'mason', 'labourer', 'construction worker', 'guard', 'industry worker', 'mason', 'factory worker', 'industry worker', 'construction worker', 'chaukidaar', 'labor', 'construction worker', 'factory worker', 'labour', 'production helper', 'mason', 'chaukidaar', 'factory worker', 'labourer', 'guard', 'security', 'ward
# ...

# %%
print(skill2)
# Out:
# ['guard', 'guard', 'warden', 'watchman', 'labour', 'production helper', 'security', 'industry worker', 'watchman', 'guard', 'security', 'construction worker', 'machine operator', 'labour', 'machine operator', 'industry worker', 'machinery handler', 'machine operator', 'machine operator', 'machine operator', 'construction worker', 'warden', 'chaukidaar', 'factory worker', 'industry worker', 'machinery handler', 'security', 'security', 'construction worker', 'guard', 'labour', 'mason', 'construction worker', 'machine operator', 'labor', 'production helper', 'machinery handler', 'chaukidaar', 'labour', 'machine operator', 'labour', 'labor', 'machine operator', 'guard', 'labour', 'machine operator', 'mason', 'labourer', 'watchman', 'warden', 'industry worker', 'production helper', 'industry worker', 'labor', 'construction worker', 'security', 'mason', 'security', 'chaukidaar', 'construction worker', 'production helper', 'guard', 'mason', 'watchman', 'warden', 'machine operator', 'mason',
# ...

# %%
s1 = np.asarray(skill1)
df['skill1'] = s1

s2 = np.asarray(skill2)
df['skill2'] = s2

# %%
df.head()
# Out:
#                 name    village  experiece             skill1    skill2
# 591           vikash  Bandakeri        NaN  production helper     guard
# 975   jitendra kumar   Budingod        NaN     factory worker     guard
# 794      anoop singh   Budingod        NaN    industry worker    warden
# 1048       durganand   Budingod        NaN              labor  watchman
# 390            kiran  Bandakeri        NaN  machinery handler    labour

# %%
df.to_csv(r'names_3.csv', index = False)

# %%
df = pd.read_csv("names_3.csv")
df.head()
# Out:
#              name    village  experiece             skill1    skill2
# 0          vikash  Bandakeri        NaN  production helper     guard
# 1  jitendra kumar   Budingod        NaN     factory worker     guard
# 2     anoop singh   Budingod        NaN    industry worker    warden
# 3       durganand   Budingod        NaN              labor  watchman
# 4           kiran  Bandakeri        NaN  machinery handler    labour

# %%
year = str(random.randint(2010, 2019))

temp=0


experience = []
for i in range(0, 1131):
    temp = i
    string1 = "from year "+str(year)+" until recently, I worked as a "+skill1[temp]+" around the village, and I have migrated to a lot of places"
    string2 = "I am currently a "+skill1[temp]+" and have been one since "+str(year)+" and I have no job since the pandemic"
    string3 = "I used to work in the city as a "+skill1[temp]+" when I started off in "+str(year)+" and I am unable to migrate since the pandemic"
    string4 = "Since "+str(year)+", I worked on many sites as "+skill1[temp]+" and I am no longer able to work"
    string5 = "I have been looking for work as a "+skill1[temp]+" for a long time now"
    string6 = "I am a "+skill1[temp]+" and things have been difficult during pandemic"
    string7 = "I work as a "+skill1[temp]+" for many years now"
    string8 = "I want to be employed as a "+skill1[temp]+" since I am out of work"
    string9 = "I used to work as a "+skill1[temp]+" and roam around for work, but I cannot anymore"
    string10 = "I am an old man working around as a "+skill1[temp]+" since "+str(year)

    explist = [string1, string2, string3, string4, string5, string6, string7, string8, string9, string10]
    expnum = random.randint(0, 9)
    experience.append(explist[expnum])
    print(experience)

# print(experience)
# Out:
# a production helper and roam around for work, but I cannot anymore', 'I am currently a labor and have been one since 2010 and I have no job since the pandemic', 'I am currently a machine operator and have been one since 2010 and I have no job since the pandemic', 'I am a guard and things have been difficult during pandemic', 'I used to work in the city as a security when I started off in 2010 and I am unable to migrate since the pandemic', 'I want to be employed as a chaukidaar since I am out of work', 'I am a mason and things have been difficult during pandemic', 'I work as a industry worker for many years now', 'from year 2010 until recently, I worked as a labour around the village, and I have migrated to a lot of places', 'I used to work as a labourer and roam around for work, but I cannot anymore', 'I work as a machine operator for many years now', 'Since 2010, I worked on many sites as machinery handler and I am no longer able to work', 'I want to be employed as a labourer since
# ...

# %%
exp = np.asarray(experience)
df['experience'] = exp

# %%
df.head()
# Out:
#              name    village  experiece             skill1    skill2  \
# 0          vikash  Bandakeri        NaN  production helper     guard
# 1  jitendra kumar   Budingod        NaN     factory worker     guard
# 2     anoop singh   Budingod        NaN    industry worker    warden
# 3       durganand   Budingod        NaN              labor  watchman
# 4           kiran  Bandakeri        NaN  machinery handler    labour
#
#                                           experience
# 0  I want to be employed as a production helper s...
# 1  I used to work in the city as a factory worker...
# 2  I am a industry worker and things have been di...
# 3  I am currently a labor and have been one since...
# 4  I used to work as a machinery handler and roam...

# %%
del df['experiece']

# %%
df.head()
# Out:
#              name    village             skill1    skill2  \
# 0          vikash  Bandakeri  production helper     guard
# 1  jitendra kumar   Budingod     factory worker     guard
# 2     anoop singh   Budingod    industry worker    warden
# 3       durganand   Budingod              labor  watchman
# 4           kiran  Bandakeri  machinery handler    labour
#
#                                           experience
# 0  I want to be employed as a production helper s...
# 1  I used to work in the city as a factory worker...
# 2  I am a industry worker and things have been di...
# 3  I am currently a labor and have been one since...
# 4  I used to work as a machinery handler and roam...

# %%
df.to_csv(r'names_final.csv', index = False)
